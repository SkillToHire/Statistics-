# %% [markdown]
# # Uniform Distribution:

# %% [markdown]
# ## 3.1.1 Discrete Probability:

# %% [markdown]
# <pre>
# A discrete probability distribution describes he probability of occurrence of each data point of a discrete random data points.
# For example, when we roll a dice, we will have six possible outcomes, we get the random data point counts.
# </pre>

# %%
#to upload image
from IPython.display import Image
Image(filename="example.png",width=800,height=800)

# %% [markdown]
# <pre>
# Here we find the probability of getting the random number when we roll a dice, using Discrete Poisson distribution we need to find the number of possible out comes in the specific time stamps, suppose when we roll a dice, the probability to occur each event is 1/6
# </pre>

# %% [markdown]
# ## 3.1.2 Continuous Probability:

# %% [markdown]
# <pre>
# A continuous distribution describes the probabilities of the possible values of a continuous random variable.
# A continuous random variable is a random variable with a set of possible values (known as the range) that is infinite   and uncountable
# </pre>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#### random weights
k2=np.random.normal(loc=30,scale=1.5,size=100)
m=np.mean(k2)
plt.figure(figsize=(10,6))
sns.distplot(k2,color="green")
plt.plot(np.full((7,1),k2.mean()),[0.00,0.05,0.10,0.15,0.20,0.25,0.30],linestyle='--',c='black')
plt.text(round(m,2),0.29, 'mean ='+str(round(m,2)))
plt.title("Continous Probability distribution")
plt.xlabel("Weights")
plt.ylabel("Probabilities")
plt.show()
